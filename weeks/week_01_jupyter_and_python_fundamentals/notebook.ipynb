# %% [markdown]
# # Week 01: Jupyter and Python Fundamentals
#
#                 **Focus:** Get comfortable with notebooks, Markdown, variables, and basic Python types.
#
#                 **Learning objectives**
#                 - Run notebook cells and write Markdown notes
# - Create variables with the main Python data types
# - Use f-strings to build readable output
#
#                 **Source materials:** Week 1.pptx, CT7201 - Python in Jupyter Tutorial Lab.pdf

# %% [markdown]
# ## Key Highlights
#
# - What Python is and why a high-level language is useful
# - How to work with Jupyter code and Markdown cells
# - Integers, floats, strings, booleans, scope, and naming

# %% [markdown]
# ## Basic values

# %%
name = "Dinis"
age = 25
height = 1.80
is_student = True

print(name)
print(age)
print(height)
print(is_student)
print(f"My name is {name}, I am {age} years old.")
# Out:
# Dinis
# 25
# 1.8
# True
# My name is Dinis, I am 25 years old.

# %% [markdown]
# ## Indentation matters

# %%
def describe_person(name: str, hobby: str) -> str:
    return f"{name} enjoys {hobby}."

print(describe_person("Dinis", "football"))
# Out:
# Dinis enjoys football.

# %% [markdown]
# ## Practice Tasks
#
# - Personal hello world: Print Hello followed by your own name.
# - Sentence builder: Create variables such as name, course, and hobby and print a sentence with an f-string.
