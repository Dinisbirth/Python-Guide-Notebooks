# %% [markdown]
# # Week 07: Scripts, Modules, and Third-Party Libraries
#
#                 **Focus:** Move beyond notebooks into scripts, imports, reusable modules, and introductory data work.
#
#                 **Learning objectives**
#                 - Explain the difference between a notebook and a script
# - Import a helper module
# - Use pandas with a reusable stats helper
#
#                 **Source materials:** Week 7 - - Other Editors, Python Files, Your own Modules, and Third Party Modules.pptx, stats.py, housing.csv

# %% [markdown]
# ## Key Highlights
#
# - The role of __main__ in Python scripts
# - Importing your own files and third-party libraries
# - Manual statistics and plotting on tabular data

# %% [markdown]
# ## Project setup

# %%
from pathlib import Path
import sys

def find_project_root(start: Path | None = None) -> Path:
    current = (start or Path.cwd()).resolve()
    for candidate in [current, *current.parents]:
        if (candidate / "requirements.txt").exists() and (candidate / "weeks").exists():
            return candidate
    return current

ROOT = find_project_root()
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

ROOT
# Out:
# WindowsPath('F:/Recovery Asus TFug/Master Degree/1º semester/Python Notebooks and Scripting/Python Notebook/ct7201-guide')

# %% [markdown]
# ## Using the Stats helper

# %%
import pandas as pd
from src.stats import Stats

housing = pd.read_csv(ROOT / "data" / "housing" / "housing.csv")
summary = Stats(housing[["median_income", "total_rooms", "median_house_value"]])

print(summary.mean())
print(summary.median())
print(summary.missing_values())
# Out:
# median_income              3.870671
# total_rooms             2635.763081
# median_house_value    206855.816909
# dtype: float64
# median_income              3.5348
# total_rooms             2127.0000
# median_house_value    179700.0000
# dtype: float64
# median_income         0
# total_rooms           0
# median_house_value    0
# dtype: int64

# %% [markdown]
# ## Practice Tasks
#
# - Explore a dataset: Load a tabular dataset, compute stats, and make a few useful plots.
# - Build a module: Move reusable logic into a .py file and import it.
